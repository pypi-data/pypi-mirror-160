# %%
import sys 
import pandas as pd

PACKAGE_FOLDER = '/Users/amash/Insync/GDrive/Projects/Raptor/raptor_functions'
sys.path.insert(0, PACKAGE_FOLDER)

# %%
from raptor_functions.supervised.preprocess import preprocess_bosch_json_files
from raptor_functions.supervised.feature_extraction import get_training_features
from raptor_functions.supervised.train import train_experiments
from raptor_functions.eda.visualisations import dimension_reduction_plot

import pandas as pd

# %%
structured_file_path_ouput = 'output'
json_file_path_peony = 'Cherry_and_Peony.json'
json_file_path_baseline = 'new_bosch_data.json'
json_file_path_vanilla = 'vanilla_new.json'

labels = ['baseline', 'peony', 'vanilla']
filepaths = [json_file_path_baseline, json_file_path_peony, json_file_path_vanilla]

# %%
df_all = preprocess_bosch_json_files(filepaths, labels, structured_file_path_ouput)
# Out:
# No of experiments for baseline is 253
# No of experiments for peony is 252
# No of experiments for vanilla is 302

# %%
cols_to_drop = ['exp_unique_id', 'timesteps', 'real_time_clock', 'result']
features = df_all.drop(cols_to_drop, axis=1).columns.tolist()

# features

# %%
df_all
# Out:
#       exp_unique_id timesteps     real_time_clock  temperature_sensor_0  \
# 0               0.0         0 2021-05-06 01:12:12             30.099798
# 1               0.0         1 2021-05-06 01:12:13             31.566181
# 2               0.0         2 2021-05-06 01:12:14             32.590897
# 3               0.0         3 2021-05-06 01:12:17             33.131020
# 4               0.0         4 2021-05-06 01:12:18             32.050774
# ...             ...       ...                 ...                   ...
# 1502          805.0         2 2021-05-02 10:21:32             41.985497
# 1503          805.0         3 2021-05-02 10:21:35             42.141998
# 1504          805.0         4 2021-05-02 10:21:36             40.872330
# 1505          806.0         0 2021-05-02 10:21:37             40.594673
# 1506          806.0         1 2021-05-02 10:21:38             41.354446
#
#       pressure_sensor_0  relative_humidity_sensor_0  \
# 0           1016.898499                   42.087475
# 1           1016.925476                   41.819595
# 2           1016.964600                   40.720627
# 3           1016.918396                   38.084511
# 4           1016.958496                   37.163151
# ...                 ...                         ...
# 1502        1017.179016                   20.339550
# 1503        1017.200928                   20.126547
# 1504        1017.210144                   19.988977
# 1505        1017.203796                   20.044756
# 1506        1017.192322                   20.265148
#
#       resistance_gas_sensor_sensor_0  temperature_sensor_1  pressure_sensor_1  \
# 0                       2.721595e+06             29.919815        1016.762390
# 1                       1.262950e+05             31.497604        1016.764893
# 2                       6.296114e+04             32.737137        1016.797424
# 3                       1.214421e+05             33.466724        1016.797729
# 4                       5.416198e+06             32.348362        1016.799561
# ...                              ...                   ...                ...
# 1502                    3.268433e+05             42.406555        1017.036560
# 1503                    4.149108e+05             42.613586        1017.059570
# 1504                    4.007093e+07             41.247688        1017.085693
# 1505                    3.729994e+07             40.927040        1017.039429
# 1506                    1.822469e+06             41.664268        1017.077026
#
#       relative_humidity_sensor_1  resistance_gas_sensor_sensor_1  \
# 0                      43.269604                    2.127792e+06
# 1                      42.967094                    1.124780e+05
# 2                      41.771393                    5.687625e+04
# 3                      38.814636                    1.088898e+05
# 4                      37.724083                    5.832680e+06
# ...                          ...                             ...
# 1502                   20.163786                    2.122280e+05
# 1503                   19.930515                    2.682735e+05
# 1504                   19.756411                    2.516260e+07
# 1505                   19.834730                    2.251323e+07
# 1506                   20.040609                    1.220864e+06
#
#       temperature_sensor_2  pressure_sensor_2  relative_humidity_sensor_2  \
# 0                30.371464        1017.123901                   41.939030
# 1                31.977152        1017.155579                   41.626842
# 2                33.211731        1017.175781                   40.443523
# 3                33.928753        1017.172852                   37.572277
# 4                32.795155        1017.191772                   36.518085
# ...                    ...                ...                         ...
# 1502             42.998081        1017.394653                   19.529427
# 1503             43.202606        1017.387573                   19.319784
# 1504             41.823967        1017.419983                   19.167376
# 1505             41.495720        1017.374023                   19.225561
# 1506             42.255737        1017.394104                   19.433270
#
#       resistance_gas_sensor_sensor_2  temperature_sensor_3  pressure_sensor_3  \
# 0                       2.144502e+06             30.074945        1017.314270
# 1                       1.098006e+05             31.700153        1017.341309
# 2                       5.468917e+04             32.957500        1017.348389
# 3                       1.083369e+05             33.748711        1017.350037
# 4                       4.262227e+06             32.614815        1017.387695
# ...                              ...                   ...                ...
# 1502                    3.162446e+05             42.706970        1017.565002
# 1503                    4.109149e+05             42.911095        1017.588257
# 1504                    3.583160e+07             41.520042        1017.598083
# 1505                    3.324169e+07             41.174805        1017.581299
# 1506                    1.789037e+06             41.945927        1017.585449
#
#       relative_humidity_sensor_3  resistance_gas_sensor_sensor_3  \
# 0                      42.065491                    2.446103e+06
# 1                      41.835030                    1.055235e+05
# 2                      40.657509                    6.272972e+04
# 3                      37.747776                    1.169484e+05
# 4                      36.677761                    5.845166e+06
# ...                          ...                             ...
# 1502                   19.495438                    2.299573e+05
# 1503                   19.281324                    2.829511e+05
# 1504                   19.128658                    2.548551e+07
# 1505                   19.290728                    2.313307e+07
# 1506                   19.408955                    1.101668e+06
#
#       temperature_sensor_4  pressure_sensor_4  relative_humidity_sensor_4  \
# 0                30.209864        1017.001526                   40.711624
# 1                31.862726        1017.066223                   40.419971
# 2                33.145229        1017.102417                   39.284870
# 3                33.918770        1017.142700                   36.456482
# 4                32.749641        1017.103577                   35.404480
# ...                    ...                ...                         ...
# 1502             41.742744        1017.394958                   19.855536
# 1503             41.972054        1017.388794                   19.652227
# 1504             40.573513        1017.407654                   19.481625
# 1505             40.271130        1017.404175                   19.557463
# 1506             40.966618        1017.388000                   19.698151
#
#       resistance_gas_sensor_sensor_4  temperature_sensor_5  pressure_sensor_5  \
# 0                       8.689011e+05             30.073557        1017.044800
# 1                       5.030458e+04             31.734610        1017.119263
# 2                       2.404659e+04             32.995613        1017.079224
# 3                       4.508630e+04             33.755264        1017.132141
# 4                       1.378660e+06             32.577812        1017.134644
# ...                              ...                   ...                ...
# 1502                    1.576840e+05             41.701569        1017.327820
# 1503                    2.037405e+05             41.909225        1017.302490
# 1504                    1.589522e+07             40.478432        1017.353577
# 1505                    1.504154e+07             40.156822        1017.299377
# 1506                    8.716748e+05             40.934258        1017.328552
#
#       relative_humidity_sensor_5  resistance_gas_sensor_sensor_5  \
# 0                      43.085331                    3.674366e+06
# 1                      42.782749                    1.600500e+05
# 2                      41.571884                    7.987520e+04
# 3                      38.632622                    1.488805e+05
# 4                      37.528839                    8.047152e+06
# ...                          ...                             ...
# 1502                   20.999470                    2.877213e+05
# 1503                   20.803383                    3.569188e+05
# 1504                   20.616426                    3.352225e+07
# 1505                   20.673092                    3.108918e+07
# 1506                   20.899153                    1.579028e+06
#
#       temperature_sensor_6  pressure_sensor_6  relative_humidity_sensor_6  \
# 0                29.968113        1017.148804                   41.818417
# 1                31.611074        1017.204773                   41.542645
# 2                32.843937        1017.202881                   40.378387
# 3                33.532455        1017.213196                   37.532791
# 4                32.364212        1017.245972                   36.486595
# ...                    ...                ...                         ...
# 1502             40.636715        1017.438416                   21.057293
# 1503             40.823158        1017.453430                   20.841705
# 1504             39.433575        1017.424011                   20.683489
# 1505             39.102962        1017.439148                   20.750959
# 1506             39.876053        1017.404114                   20.941227
#
#       resistance_gas_sensor_sensor_6  temperature_sensor_7  pressure_sensor_7  \
# 0                       1.049180e+06             30.034039        1017.266785
# 1                       5.756690e+04             31.657578        1017.319336
# 2                       2.968460e+04             32.892296        1017.339111
# 3                       5.649967e+04             33.654850        1017.348083
# 4                       1.918501e+06             32.460518        1017.345825
# ...                              ...                   ...                ...
# 1502                    1.780870e+05             40.927197        1017.520447
# 1503                    2.302676e+05             39.530762        1017.545593
# 1504                    1.983535e+07             39.237839        1017.517090
# 1505                    1.847646e+07             39.944893        1017.504456
# 1506                    9.466143e+05             40.755486        1017.513428
#
#       relative_humidity_sensor_7  resistance_gas_sensor_sensor_7    result
# 0                      42.907742                    7.109568e+06  baseline
# 1                      42.577545                    3.488927e+05  baseline
# 2                      41.434841                    9.767264e+04  baseline
# 3                      38.509724                    1.767956e+05  baseline
# 4                      37.436543                    1.113044e+07  baseline
# ...                          ...                             ...       ...
# 1502                   21.590275                    3.996098e+05   vanilla
# 1503                   21.407076                    4.136068e+07   vanilla
# 1504                   21.471504                    3.956293e+07   vanilla
# 1505                   21.680540                    2.164905e+06   vanilla
# 1506                   21.828718                    3.198001e+05   vanilla
#
# [4029 rows x 36 columns]

# %%
timesteps = 'real_time_clock'
df_train = get_training_features(df_all,timesteps=timesteps, features=features)

# %%
df_train.columns

# %%
X = df_train.drop('result', axis=1)
y = df_train['result']

dimension_reduction_plot(X, y)

# %%
import mlflow

mlflow.end_run()
train_experiments(df_train, study_name='bosch')
